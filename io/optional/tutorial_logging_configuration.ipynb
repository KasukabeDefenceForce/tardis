# %% [markdown]
# # Configuring the Logging Output for TARDIS

# %% [markdown]
# **TARDIS** has a Notebook logger that logs information of Simulation runs. The logs allows to access vital information regarding the execution sequence, data for plasma stratification & progress of the simulation.<br>
# **TARDIS** allows configuring the logger via *Functional Arguments* as well as *YAML Parameters*.
# The following code snippets are some of the possible configuration that is available for the notebook logging done with TARDIS simulation.

# %% [markdown]
# ## Default Configuration

# %% [markdown]
# The default configuration of the Notebook Simulation logger is such that it doesn't output any logs.

# %% [markdown]
# The output simulation logging, while executing the **TARDIS** simulation (default behaviour), can be seen below:

# %%
from tardis import run_tardis
from tardis.io.atom_data.util import download_atom_data
# Out:
# /home/runner/micromamba/envs/tardis/lib/python3.12/site-packages/setuptools_scm/git.py:167: UserWarning: "/home/runner/work/tardis/tardis" is shallow and may cause errors
#   warnings.warn(f'"{wd.path}" is shallow and may cause errors')
# Iterations:          0/? [00:00<?, ?it/s]
# Packets:             0/? [00:00<?, ?it/s]

# %%
# We download the atomic data needed to run the simulation
download_atom_data('kurucz_cd23_chianti_H_He')
# Out:
# Atomic Data kurucz_cd23_chianti_H_He already exists in /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5. Will not download - override with force_download=True.

# %%
sim = run_tardis("tardis_config_logger.yml", show_cplots=False)
# Out:
# [py.warnings         ][WARNING]
# 	/home/runner/work/tardis/tardis/tardis/transport/montecarlo/montecarlo_main_loop.py:142: NumbaTypeSafetyWarning: unsafe cast from uint64 to int64. Precision may be lost.
#   vpacket_collection = vpacket_collections[i]
#  (warnings.py:112)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…

# %% [markdown]
# It can be examined that the logs are not printed.<br> The logging level, by default, is set to `CRITICAL`. Logs will only be captured if any `CRITICAL` level logs are encountered while running the simulation.

# %% [markdown]
# ## Logging Configuration (Functional Arguments)

# %% [markdown]
# The `run_tardis()` function from the `tardis module` has two functional arguments:`log_level` & `specific_log_level`.

# %% [markdown]
# <div class="alert alert-info">
#
# Note
#
# Both <strong>log_level</strong> & <strong>specific</strong> are optional arguments for the <strong>run_tardis()</strong> function, however, if <strong>specific</strong> argument is used then, <strong>log_level</strong> must be set to a particular level.
# </div>

# %% [markdown]
# ### The `log_level` Argument

# %% [markdown]
# The `log_level` argument can be passed in `run_tardis()` to set the logging level for the simulation. The input for this argument **must be** one of the following: **Notset, Debug, Info, Warning, Error** or **Critical**.

# %%
sim = run_tardis("tardis_config_logger.yml", log_level="Info", show_cplots=False)
# Out:
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = INFO will be used for Log Level Determination
#
# [tardis.io.model.parse_atom_data][INFO   ]
#
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (parse_atom_data.py:40)
# [tardis.io.atom_data.util][INFO   ]
#
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:36)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:258)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data, linelist (base.py:262)
# [tardis.io.model.parse_density_configuration][WARNING]
# 	Number of density points larger than number of shells. Assuming inner point irrelevant (parse_density_configuration.py:114)
# [tardis.model.matter.decay][INFO   ]
# 	Decaying abundances for 1123200.0 seconds (decay.py:101)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 1 of 5 (base.py:376)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_e7e28">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_e7e28_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_e7e28_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_e7e28_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_e7e28_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7e28_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7e28_row0_col0" class="data row0 col0" >9.93e+03 K</td>
#       <td id="T_e7e28_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_e7e28_row0_col2" class="data row0 col2" >0.4</td>
#       <td id="T_e7e28_row0_col3" class="data row0 col3" >0.481</td>
#     </tr>
#     <tr>
#       <th id="T_e7e28_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_e7e28_row1_col0" class="data row1 col0" >9.85e+03 K</td>
#       <td id="T_e7e28_row1_col1" class="data row1 col1" >1.03e+04 K</td>
#       <td id="T_e7e28_row1_col2" class="data row1 col2" >0.211</td>
#       <td id="T_e7e28_row1_col3" class="data row1 col3" >0.193</td>
#     </tr>
#     <tr>
#       <th id="T_e7e28_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_e7e28_row2_col0" class="data row2 col0" >9.78e+03 K</td>
#       <td id="T_e7e28_row2_col1" class="data row2 col1" >1.02e+04 K</td>
#       <td id="T_e7e28_row2_col2" class="data row2 col2" >0.143</td>
#       <td id="T_e7e28_row2_col3" class="data row2 col3" >0.112</td>
#     </tr>
#     <tr>
#       <th id="T_e7e28_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_e7e28_row3_col0" class="data row3 col0" >9.71e+03 K</td>
#       <td id="T_e7e28_row3_col1" class="data row3 col1" >9.98e+03 K</td>
#       <td id="T_e7e28_row3_col2" class="data row3 col2" >0.105</td>
#       <td id="T_e7e28_row3_col3" class="data row3 col3" >0.0826</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 2 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_f968f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_f968f_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_f968f_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_f968f_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_f968f_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f968f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f968f_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_f968f_row0_col1" class="data row0 col1" >1.15e+04 K</td>
#       <td id="T_f968f_row0_col2" class="data row0 col2" >0.481</td>
#       <td id="T_f968f_row0_col3" class="data row0 col3" >0.555</td>
#     </tr>
#     <tr>
#       <th id="T_f968f_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_f968f_row1_col0" class="data row1 col0" >1.03e+04 K</td>
#       <td id="T_f968f_row1_col1" class="data row1 col1" >1.17e+04 K</td>
#       <td id="T_f968f_row1_col2" class="data row1 col2" >0.193</td>
#       <td id="T_f968f_row1_col3" class="data row1 col3" >0.203</td>
#     </tr>
#     <tr>
#       <th id="T_f968f_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_f968f_row2_col0" class="data row2 col0" >1.02e+04 K</td>
#       <td id="T_f968f_row2_col1" class="data row2 col1" >1.13e+04 K</td>
#       <td id="T_f968f_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_f968f_row2_col3" class="data row2 col3" >0.135</td>
#     </tr>
#     <tr>
#       <th id="T_f968f_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_f968f_row3_col0" class="data row3 col0" >9.98e+03 K</td>
#       <td id="T_f968f_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_f968f_row3_col2" class="data row3 col2" >0.0826</td>
#       <td id="T_f968f_row3_col3" class="data row3 col3" >0.0998</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 3 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_e88d9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_e88d9_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_e88d9_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_e88d9_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_e88d9_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e88d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e88d9_row0_col0" class="data row0 col0" >1.15e+04 K</td>
#       <td id="T_e88d9_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_e88d9_row0_col2" class="data row0 col2" >0.555</td>
#       <td id="T_e88d9_row0_col3" class="data row0 col3" >0.468</td>
#     </tr>
#     <tr>
#       <th id="T_e88d9_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_e88d9_row1_col0" class="data row1 col0" >1.17e+04 K</td>
#       <td id="T_e88d9_row1_col1" class="data row1 col1" >1.05e+04 K</td>
#       <td id="T_e88d9_row1_col2" class="data row1 col2" >0.203</td>
#       <td id="T_e88d9_row1_col3" class="data row1 col3" >0.181</td>
#     </tr>
#     <tr>
#       <th id="T_e88d9_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_e88d9_row2_col0" class="data row2 col0" >1.13e+04 K</td>
#       <td id="T_e88d9_row2_col1" class="data row2 col1" >1.05e+04 K</td>
#       <td id="T_e88d9_row2_col2" class="data row2 col2" >0.135</td>
#       <td id="T_e88d9_row2_col3" class="data row2 col3" >0.108</td>
#     </tr>
#     <tr>
#       <th id="T_e88d9_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_e88d9_row3_col0" class="data row3 col0" >1.1e+04 K</td>
#       <td id="T_e88d9_row3_col1" class="data row3 col1" >1.03e+04 K</td>
#       <td id="T_e88d9_row3_col2" class="data row3 col2" >0.0998</td>
#       <td id="T_e88d9_row3_col3" class="data row3 col3" >0.0779</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 4 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_71b13">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_71b13_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_71b13_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_71b13_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_71b13_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71b13_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71b13_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_71b13_row0_col1" class="data row0 col1" >1.14e+04 K</td>
#       <td id="T_71b13_row0_col2" class="data row0 col2" >0.468</td>
#       <td id="T_71b13_row0_col3" class="data row0 col3" >0.527</td>
#     </tr>
#     <tr>
#       <th id="T_71b13_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_71b13_row1_col0" class="data row1 col0" >1.05e+04 K</td>
#       <td id="T_71b13_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_71b13_row1_col2" class="data row1 col2" >0.181</td>
#       <td id="T_71b13_row1_col3" class="data row1 col3" >0.225</td>
#     </tr>
#     <tr>
#       <th id="T_71b13_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_71b13_row2_col0" class="data row2 col0" >1.05e+04 K</td>
#       <td id="T_71b13_row2_col1" class="data row2 col1" >1.12e+04 K</td>
#       <td id="T_71b13_row2_col2" class="data row2 col2" >0.108</td>
#       <td id="T_71b13_row2_col3" class="data row2 col3" >0.126</td>
#     </tr>
#     <tr>
#       <th id="T_71b13_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_71b13_row3_col0" class="data row3 col0" >1.03e+04 K</td>
#       <td id="T_71b13_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_71b13_row3_col2" class="data row3 col2" >0.0779</td>
#       <td id="T_71b13_row3_col3" class="data row3 col3" >0.0926</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Simulation finished in 4 iterations
# 	Simulation took 0.42 s
#  (base.py:458)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 5 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)

# %% [markdown]
# By setting up the `log_level` parameter to **"Info"** in the above example, we can check that the logs are at the **"Info"** or higher logging level.

# %% [markdown]
# ### The `specific` Argument

# %% [markdown]
# The `specific_log_level` argument tells the logger to capture log messages set by the `log_level` parameter. It can only take *Boolean* values for input, which are `True` or `False`. Take for example the following:

# %%
sim = run_tardis("tardis_config_logger.yml", log_level="Debug", specific_log_level=True, show_cplots=False)
# Out:
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = DEBUG will be used for Log Level Determination
#
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain synpp_refs column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain photoionization_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain yg_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain two_photon_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain linelist column (base.py:181)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->SelectedAtoms->BetaRadiation->ElectronTemperature->Levels->Lines->IonizationData->MacroAtomData->GElectron->LevelBoltzmannFactorLTE->LinesLowerLevelIndex->LinesUpperLevelIndex->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->SelectedAtoms->BetaRadiation->ElectronTemperature->Levels->Lines->IonizationData->MacroAtomData->GElectron->LevelBoltzmannFactorLTE->LinesLowerLevelIndex->LinesUpperLevelIndex->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.transport.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:243)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)

# %% [markdown]
# It can be examined that, when we set `specific_log_level` to `True`, the log messages captured were only at the `DEBUG` log level.<br> This allows for logging only specified logging messages for inspection.

# %% [markdown]
# The changes in the captured log messages can be seen when we set `specific_log_level` to `False`.

# %%
sim = run_tardis("tardis_config_logger.yml", log_level="Debug", specific_log_level=False, show_cplots=False)
# Out:
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = DEBUG will be used for Log Level Determination
#
# [tardis.io.model.parse_atom_data][INFO   ]
#
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (parse_atom_data.py:40)
# [tardis.io.atom_data.util][INFO   ]
#
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:36)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain synpp_refs column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain photoionization_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain yg_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain two_photon_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain linelist column (base.py:181)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:258)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data, linelist (base.py:262)
# [tardis.io.model.parse_density_configuration][WARNING]
# 	Number of density points larger than number of shells. Assuming inner point irrelevant (parse_density_configuration.py:114)
# [tardis.model.matter.decay][INFO   ]
# 	Decaying abundances for 1123200.0 seconds (decay.py:101)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->SelectedAtoms->BetaRadiation->ElectronTemperature->Levels->Lines->IonizationData->MacroAtomData->GElectron->LevelBoltzmannFactorLTE->LinesLowerLevelIndex->LinesUpperLevelIndex->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->SelectedAtoms->BetaRadiation->ElectronTemperature->Levels->Lines->IonizationData->MacroAtomData->GElectron->LevelBoltzmannFactorLTE->LinesLowerLevelIndex->LinesUpperLevelIndex->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.transport.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:243)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 1 of 5 (base.py:376)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_4c0e9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_4c0e9_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_4c0e9_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_4c0e9_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_4c0e9_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c0e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c0e9_row0_col0" class="data row0 col0" >9.93e+03 K</td>
#       <td id="T_4c0e9_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_4c0e9_row0_col2" class="data row0 col2" >0.4</td>
#       <td id="T_4c0e9_row0_col3" class="data row0 col3" >0.481</td>
#     </tr>
#     <tr>
#       <th id="T_4c0e9_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_4c0e9_row1_col0" class="data row1 col0" >9.85e+03 K</td>
#       <td id="T_4c0e9_row1_col1" class="data row1 col1" >1.03e+04 K</td>
#       <td id="T_4c0e9_row1_col2" class="data row1 col2" >0.211</td>
#       <td id="T_4c0e9_row1_col3" class="data row1 col3" >0.193</td>
#     </tr>
#     <tr>
#       <th id="T_4c0e9_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_4c0e9_row2_col0" class="data row2 col0" >9.78e+03 K</td>
#       <td id="T_4c0e9_row2_col1" class="data row2 col1" >1.02e+04 K</td>
#       <td id="T_4c0e9_row2_col2" class="data row2 col2" >0.143</td>
#       <td id="T_4c0e9_row2_col3" class="data row2 col3" >0.112</td>
#     </tr>
#     <tr>
#       <th id="T_4c0e9_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_4c0e9_row3_col0" class="data row3 col0" >9.71e+03 K</td>
#       <td id="T_4c0e9_row3_col1" class="data row3 col1" >9.98e+03 K</td>
#       <td id="T_4c0e9_row3_col2" class="data row3 col2" >0.105</td>
#       <td id="T_4c0e9_row3_col3" class="data row3 col3" >0.0826</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:562)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 2 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_17f4e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_17f4e_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_17f4e_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_17f4e_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_17f4e_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17f4e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17f4e_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_17f4e_row0_col1" class="data row0 col1" >1.15e+04 K</td>
#       <td id="T_17f4e_row0_col2" class="data row0 col2" >0.481</td>
#       <td id="T_17f4e_row0_col3" class="data row0 col3" >0.555</td>
#     </tr>
#     <tr>
#       <th id="T_17f4e_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_17f4e_row1_col0" class="data row1 col0" >1.03e+04 K</td>
#       <td id="T_17f4e_row1_col1" class="data row1 col1" >1.17e+04 K</td>
#       <td id="T_17f4e_row1_col2" class="data row1 col2" >0.193</td>
#       <td id="T_17f4e_row1_col3" class="data row1 col3" >0.203</td>
#     </tr>
#     <tr>
#       <th id="T_17f4e_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_17f4e_row2_col0" class="data row2 col0" >1.02e+04 K</td>
#       <td id="T_17f4e_row2_col1" class="data row2 col1" >1.13e+04 K</td>
#       <td id="T_17f4e_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_17f4e_row2_col3" class="data row2 col3" >0.135</td>
#     </tr>
#     <tr>
#       <th id="T_17f4e_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_17f4e_row3_col0" class="data row3 col0" >9.98e+03 K</td>
#       <td id="T_17f4e_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_17f4e_row3_col2" class="data row3 col2" >0.0826</td>
#       <td id="T_17f4e_row3_col3" class="data row3 col3" >0.0998</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:562)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 3 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_0674f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_0674f_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_0674f_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_0674f_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_0674f_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0674f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0674f_row0_col0" class="data row0 col0" >1.15e+04 K</td>
#       <td id="T_0674f_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_0674f_row0_col2" class="data row0 col2" >0.555</td>
#       <td id="T_0674f_row0_col3" class="data row0 col3" >0.468</td>
#     </tr>
#     <tr>
#       <th id="T_0674f_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_0674f_row1_col0" class="data row1 col0" >1.17e+04 K</td>
#       <td id="T_0674f_row1_col1" class="data row1 col1" >1.05e+04 K</td>
#       <td id="T_0674f_row1_col2" class="data row1 col2" >0.203</td>
#       <td id="T_0674f_row1_col3" class="data row1 col3" >0.181</td>
#     </tr>
#     <tr>
#       <th id="T_0674f_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_0674f_row2_col0" class="data row2 col0" >1.13e+04 K</td>
#       <td id="T_0674f_row2_col1" class="data row2 col1" >1.05e+04 K</td>
#       <td id="T_0674f_row2_col2" class="data row2 col2" >0.135</td>
#       <td id="T_0674f_row2_col3" class="data row2 col3" >0.108</td>
#     </tr>
#     <tr>
#       <th id="T_0674f_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_0674f_row3_col0" class="data row3 col0" >1.1e+04 K</td>
#       <td id="T_0674f_row3_col1" class="data row3 col1" >1.03e+04 K</td>
#       <td id="T_0674f_row3_col2" class="data row3 col2" >0.0998</td>
#       <td id="T_0674f_row3_col3" class="data row3 col3" >0.0779</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:562)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 4 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_d0f11">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_d0f11_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_d0f11_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_d0f11_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_d0f11_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0f11_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0f11_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_d0f11_row0_col1" class="data row0 col1" >1.14e+04 K</td>
#       <td id="T_d0f11_row0_col2" class="data row0 col2" >0.468</td>
#       <td id="T_d0f11_row0_col3" class="data row0 col3" >0.527</td>
#     </tr>
#     <tr>
#       <th id="T_d0f11_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_d0f11_row1_col0" class="data row1 col0" >1.05e+04 K</td>
#       <td id="T_d0f11_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_d0f11_row1_col2" class="data row1 col2" >0.181</td>
#       <td id="T_d0f11_row1_col3" class="data row1 col3" >0.225</td>
#     </tr>
#     <tr>
#       <th id="T_d0f11_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_d0f11_row2_col0" class="data row2 col0" >1.05e+04 K</td>
#       <td id="T_d0f11_row2_col1" class="data row2 col1" >1.12e+04 K</td>
#       <td id="T_d0f11_row2_col2" class="data row2 col2" >0.108</td>
#       <td id="T_d0f11_row2_col3" class="data row2 col3" >0.126</td>
#     </tr>
#     <tr>
#       <th id="T_d0f11_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_d0f11_row3_col0" class="data row3 col0" >1.03e+04 K</td>
#       <td id="T_d0f11_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_d0f11_row3_col2" class="data row3 col2" >0.0779</td>
#       <td id="T_d0f11_row3_col3" class="data row3 col3" >0.0926</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:562)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.simulation.base][INFO   ]
#
# 	Simulation finished in 4 iterations
# 	Simulation took 0.35 s
#  (base.py:458)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 5 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)

# %% [markdown]
# It can be examined in this example that when we kept `specific_log_level` to `False`, the captured log output includes all log messages from `DEBUG` and higher logging levels, which is the default behavior of the logger.

# %% [markdown]
# ## Logging Configuration (YAML Configuration)

# %% [markdown]
# The behavior of the logging output for the simulation can be configured via the `tardis_config_logger.yml` *(**YAML** Configuration)* file. For setting up the logger via the YAML file, the configuration file must include a `debug` section. An example configuration for the `debug` section can be seen below:

# %% [markdown]
# ```YAML
# ...
# debug:
#   log_level: "Info"
#   specific_log_level : False
# ```

# %% [markdown]
# The `debug` schema includes the `log_level` & `specific_log_level` parameters.

# %% [markdown]
# <div class="alert alert-info">
#
# Note
#
# The <strong>debug</strong> section of the <strong>YAML</strong> config file is <i>optional</i>. The <strong>log_level</strong> and the <strong>specific</strong> arguments are <i>optional</i> as well. If none of the parameters are defined, then the values of these parameter fall back on the <strong>default values</strong>.
# </div>

# %% [markdown]
# Let us load the `tardis_config_logger.yml` configuration to a variable & check out the schema:

# %%
from tardis.io.configuration.config_reader import Configuration

# %%
# Loading the Schema 
config = Configuration.from_yaml("tardis_config_logger.yml")

# Checking the Debug Schema via dictionary
config["debug"]
# Out:
# {'specific_log_level': False, 'log_level': 'Critical'}

# %% [markdown]
# ### The `log_level` Entry

# %% [markdown]
# The `log_level` parameter, in the `debug` section of the config file, is similar in functionality to the `log_level` functional argument that can be passed via the `run_tardis()` function. The value of this parameter **must be** one of the following: **Notset, Debug, Info, Warning, Error** or **Critical**.

# %% [markdown]
# Let us see an example of the captured simulation logging output, when the `log_level` parameter is set to `"Info"` log level in the `tardis_config_logger.yml` config file.

# %%
config["debug"]["log_level"] = "Info"

# %%
# Running the simulation by passing the config dictionary to `run_tardis()` function
sim = run_tardis(config, show_cplots=False)
# Out:
# [tardis.io.model.parse_atom_data][INFO   ]
#
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (parse_atom_data.py:40)
# [tardis.io.atom_data.util][INFO   ]
#
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:36)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:258)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data, linelist (base.py:262)
# [tardis.io.model.parse_density_configuration][WARNING]
# 	Number of density points larger than number of shells. Assuming inner point irrelevant (parse_density_configuration.py:114)
# [tardis.model.matter.decay][INFO   ]
# 	Decaying abundances for 1123200.0 seconds (decay.py:101)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 1 of 5 (base.py:376)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_7a14b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_7a14b_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_7a14b_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_7a14b_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_7a14b_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a14b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a14b_row0_col0" class="data row0 col0" >9.93e+03 K</td>
#       <td id="T_7a14b_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_7a14b_row0_col2" class="data row0 col2" >0.4</td>
#       <td id="T_7a14b_row0_col3" class="data row0 col3" >0.481</td>
#     </tr>
#     <tr>
#       <th id="T_7a14b_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_7a14b_row1_col0" class="data row1 col0" >9.85e+03 K</td>
#       <td id="T_7a14b_row1_col1" class="data row1 col1" >1.03e+04 K</td>
#       <td id="T_7a14b_row1_col2" class="data row1 col2" >0.211</td>
#       <td id="T_7a14b_row1_col3" class="data row1 col3" >0.193</td>
#     </tr>
#     <tr>
#       <th id="T_7a14b_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_7a14b_row2_col0" class="data row2 col0" >9.78e+03 K</td>
#       <td id="T_7a14b_row2_col1" class="data row2 col1" >1.02e+04 K</td>
#       <td id="T_7a14b_row2_col2" class="data row2 col2" >0.143</td>
#       <td id="T_7a14b_row2_col3" class="data row2 col3" >0.112</td>
#     </tr>
#     <tr>
#       <th id="T_7a14b_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_7a14b_row3_col0" class="data row3 col0" >9.71e+03 K</td>
#       <td id="T_7a14b_row3_col1" class="data row3 col1" >9.98e+03 K</td>
#       <td id="T_7a14b_row3_col2" class="data row3 col2" >0.105</td>
#       <td id="T_7a14b_row3_col3" class="data row3 col3" >0.0826</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 2 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_21cad">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_21cad_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_21cad_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_21cad_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_21cad_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21cad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21cad_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_21cad_row0_col1" class="data row0 col1" >1.15e+04 K</td>
#       <td id="T_21cad_row0_col2" class="data row0 col2" >0.481</td>
#       <td id="T_21cad_row0_col3" class="data row0 col3" >0.555</td>
#     </tr>
#     <tr>
#       <th id="T_21cad_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_21cad_row1_col0" class="data row1 col0" >1.03e+04 K</td>
#       <td id="T_21cad_row1_col1" class="data row1 col1" >1.17e+04 K</td>
#       <td id="T_21cad_row1_col2" class="data row1 col2" >0.193</td>
#       <td id="T_21cad_row1_col3" class="data row1 col3" >0.203</td>
#     </tr>
#     <tr>
#       <th id="T_21cad_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_21cad_row2_col0" class="data row2 col0" >1.02e+04 K</td>
#       <td id="T_21cad_row2_col1" class="data row2 col1" >1.13e+04 K</td>
#       <td id="T_21cad_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_21cad_row2_col3" class="data row2 col3" >0.135</td>
#     </tr>
#     <tr>
#       <th id="T_21cad_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_21cad_row3_col0" class="data row3 col0" >9.98e+03 K</td>
#       <td id="T_21cad_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_21cad_row3_col2" class="data row3 col2" >0.0826</td>
#       <td id="T_21cad_row3_col3" class="data row3 col3" >0.0998</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 3 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_333a9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_333a9_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_333a9_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_333a9_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_333a9_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_333a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_333a9_row0_col0" class="data row0 col0" >1.15e+04 K</td>
#       <td id="T_333a9_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_333a9_row0_col2" class="data row0 col2" >0.555</td>
#       <td id="T_333a9_row0_col3" class="data row0 col3" >0.468</td>
#     </tr>
#     <tr>
#       <th id="T_333a9_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_333a9_row1_col0" class="data row1 col0" >1.17e+04 K</td>
#       <td id="T_333a9_row1_col1" class="data row1 col1" >1.05e+04 K</td>
#       <td id="T_333a9_row1_col2" class="data row1 col2" >0.203</td>
#       <td id="T_333a9_row1_col3" class="data row1 col3" >0.181</td>
#     </tr>
#     <tr>
#       <th id="T_333a9_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_333a9_row2_col0" class="data row2 col0" >1.13e+04 K</td>
#       <td id="T_333a9_row2_col1" class="data row2 col1" >1.05e+04 K</td>
#       <td id="T_333a9_row2_col2" class="data row2 col2" >0.135</td>
#       <td id="T_333a9_row2_col3" class="data row2 col3" >0.108</td>
#     </tr>
#     <tr>
#       <th id="T_333a9_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_333a9_row3_col0" class="data row3 col0" >1.1e+04 K</td>
#       <td id="T_333a9_row3_col1" class="data row3 col1" >1.03e+04 K</td>
#       <td id="T_333a9_row3_col2" class="data row3 col2" >0.0998</td>
#       <td id="T_333a9_row3_col3" class="data row3 col3" >0.0779</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 4 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_cfdd7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_cfdd7_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_cfdd7_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_cfdd7_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_cfdd7_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfdd7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cfdd7_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_cfdd7_row0_col1" class="data row0 col1" >1.14e+04 K</td>
#       <td id="T_cfdd7_row0_col2" class="data row0 col2" >0.468</td>
#       <td id="T_cfdd7_row0_col3" class="data row0 col3" >0.527</td>
#     </tr>
#     <tr>
#       <th id="T_cfdd7_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_cfdd7_row1_col0" class="data row1 col0" >1.05e+04 K</td>
#       <td id="T_cfdd7_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_cfdd7_row1_col2" class="data row1 col2" >0.181</td>
#       <td id="T_cfdd7_row1_col3" class="data row1 col3" >0.225</td>
#     </tr>
#     <tr>
#       <th id="T_cfdd7_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_cfdd7_row2_col0" class="data row2 col0" >1.05e+04 K</td>
#       <td id="T_cfdd7_row2_col1" class="data row2 col1" >1.12e+04 K</td>
#       <td id="T_cfdd7_row2_col2" class="data row2 col2" >0.108</td>
#       <td id="T_cfdd7_row2_col3" class="data row2 col3" >0.126</td>
#     </tr>
#     <tr>
#       <th id="T_cfdd7_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_cfdd7_row3_col0" class="data row3 col0" >1.03e+04 K</td>
#       <td id="T_cfdd7_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_cfdd7_row3_col2" class="data row3 col2" >0.0779</td>
#       <td id="T_cfdd7_row3_col3" class="data row3 col3" >0.0926</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Simulation finished in 4 iterations
# 	Simulation took 0.36 s
#  (base.py:458)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 5 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)

# %% [markdown]
# ### The `specific` Entry

# %% [markdown]
# The `specific_log_level` parameter in the `debug` section of the schema is similar in functionality to the `specific_log_level` functional argument. It takes **Boolean** values, i.e., `True` or `False`. It is an optional parameter.

# %% [markdown]
# Let us see an example when we set `specific_log_level` to `True` at the `Debug` level.

# %%
config["debug"]["log_level"] = "Debug"
config["debug"]["specific_log_level"] = True

# %%
sim = run_tardis(config, show_cplots=False)
# Out:
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain synpp_refs column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain photoionization_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain yg_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain two_photon_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain linelist column (base.py:181)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->SelectedAtoms->BetaRadiation->ElectronTemperature->Levels->Lines->IonizationData->MacroAtomData->GElectron->LevelBoltzmannFactorLTE->LinesLowerLevelIndex->LinesUpperLevelIndex->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->SelectedAtoms->BetaRadiation->ElectronTemperature->Levels->Lines->IonizationData->MacroAtomData->GElectron->LevelBoltzmannFactorLTE->LinesLowerLevelIndex->LinesUpperLevelIndex->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.transport.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:243)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)

# %% [markdown]
# Setting `specific_log_level` to `False` to check the actual output at the `DEBUG` level for the simulation logs.

# %%
config["debug"]["specific_log_level"] = False

# %%
sim = run_tardis(config,show_cplots=False)
# Out:
# [tardis.io.model.parse_atom_data][INFO   ]
#
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (parse_atom_data.py:40)
# [tardis.io.atom_data.util][INFO   ]
#
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:36)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain synpp_refs column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain photoionization_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain yg_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain two_photon_data column (base.py:181)
# [tardis.io.atom_data.base][DEBUG  ]  Dataframe does not contain linelist column (base.py:181)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:258)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data, linelist (base.py:262)
# [tardis.io.model.parse_density_configuration][WARNING]
# 	Number of density points larger than number of shells. Assuming inner point irrelevant (parse_density_configuration.py:114)
# [tardis.model.matter.decay][INFO   ]
# 	Decaying abundances for 1123200.0 seconds (decay.py:101)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->SelectedAtoms->BetaRadiation->ElectronTemperature->Levels->Lines->IonizationData->MacroAtomData->GElectron->LevelBoltzmannFactorLTE->LinesLowerLevelIndex->LinesUpperLevelIndex->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->SelectedAtoms->BetaRadiation->ElectronTemperature->Levels->Lines->IonizationData->MacroAtomData->GElectron->LevelBoltzmannFactorLTE->LinesLowerLevelIndex->LinesUpperLevelIndex->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.transport.montecarlo.base][DEBUG  ]  Electron scattering switched on (base.py:243)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 1 of 5 (base.py:376)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_9bc24">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_9bc24_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_9bc24_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_9bc24_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_9bc24_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bc24_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bc24_row0_col0" class="data row0 col0" >9.93e+03 K</td>
#       <td id="T_9bc24_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_9bc24_row0_col2" class="data row0 col2" >0.4</td>
#       <td id="T_9bc24_row0_col3" class="data row0 col3" >0.481</td>
#     </tr>
#     <tr>
#       <th id="T_9bc24_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_9bc24_row1_col0" class="data row1 col0" >9.85e+03 K</td>
#       <td id="T_9bc24_row1_col1" class="data row1 col1" >1.03e+04 K</td>
#       <td id="T_9bc24_row1_col2" class="data row1 col2" >0.211</td>
#       <td id="T_9bc24_row1_col3" class="data row1 col3" >0.193</td>
#     </tr>
#     <tr>
#       <th id="T_9bc24_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_9bc24_row2_col0" class="data row2 col0" >9.78e+03 K</td>
#       <td id="T_9bc24_row2_col1" class="data row2 col1" >1.02e+04 K</td>
#       <td id="T_9bc24_row2_col2" class="data row2 col2" >0.143</td>
#       <td id="T_9bc24_row2_col3" class="data row2 col3" >0.112</td>
#     </tr>
#     <tr>
#       <th id="T_9bc24_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_9bc24_row3_col0" class="data row3 col0" >9.71e+03 K</td>
#       <td id="T_9bc24_row3_col1" class="data row3 col1" >9.98e+03 K</td>
#       <td id="T_9bc24_row3_col2" class="data row3 col2" >0.105</td>
#       <td id="T_9bc24_row3_col3" class="data row3 col3" >0.0826</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:562)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 2 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_f0a18">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_f0a18_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_f0a18_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_f0a18_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_f0a18_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0a18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0a18_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_f0a18_row0_col1" class="data row0 col1" >1.15e+04 K</td>
#       <td id="T_f0a18_row0_col2" class="data row0 col2" >0.481</td>
#       <td id="T_f0a18_row0_col3" class="data row0 col3" >0.555</td>
#     </tr>
#     <tr>
#       <th id="T_f0a18_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_f0a18_row1_col0" class="data row1 col0" >1.03e+04 K</td>
#       <td id="T_f0a18_row1_col1" class="data row1 col1" >1.17e+04 K</td>
#       <td id="T_f0a18_row1_col2" class="data row1 col2" >0.193</td>
#       <td id="T_f0a18_row1_col3" class="data row1 col3" >0.203</td>
#     </tr>
#     <tr>
#       <th id="T_f0a18_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_f0a18_row2_col0" class="data row2 col0" >1.02e+04 K</td>
#       <td id="T_f0a18_row2_col1" class="data row2 col1" >1.13e+04 K</td>
#       <td id="T_f0a18_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_f0a18_row2_col3" class="data row2 col3" >0.135</td>
#     </tr>
#     <tr>
#       <th id="T_f0a18_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_f0a18_row3_col0" class="data row3 col0" >9.98e+03 K</td>
#       <td id="T_f0a18_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_f0a18_row3_col2" class="data row3 col2" >0.0826</td>
#       <td id="T_f0a18_row3_col3" class="data row3 col3" >0.0998</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:562)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 3 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_b21c6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_b21c6_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_b21c6_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_b21c6_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_b21c6_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b21c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b21c6_row0_col0" class="data row0 col0" >1.15e+04 K</td>
#       <td id="T_b21c6_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_b21c6_row0_col2" class="data row0 col2" >0.555</td>
#       <td id="T_b21c6_row0_col3" class="data row0 col3" >0.468</td>
#     </tr>
#     <tr>
#       <th id="T_b21c6_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_b21c6_row1_col0" class="data row1 col0" >1.17e+04 K</td>
#       <td id="T_b21c6_row1_col1" class="data row1 col1" >1.05e+04 K</td>
#       <td id="T_b21c6_row1_col2" class="data row1 col2" >0.203</td>
#       <td id="T_b21c6_row1_col3" class="data row1 col3" >0.181</td>
#     </tr>
#     <tr>
#       <th id="T_b21c6_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_b21c6_row2_col0" class="data row2 col0" >1.13e+04 K</td>
#       <td id="T_b21c6_row2_col1" class="data row2 col1" >1.05e+04 K</td>
#       <td id="T_b21c6_row2_col2" class="data row2 col2" >0.135</td>
#       <td id="T_b21c6_row2_col3" class="data row2 col3" >0.108</td>
#     </tr>
#     <tr>
#       <th id="T_b21c6_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_b21c6_row3_col0" class="data row3 col0" >1.1e+04 K</td>
#       <td id="T_b21c6_row3_col1" class="data row3 col1" >1.03e+04 K</td>
#       <td id="T_b21c6_row3_col2" class="data row3 col2" >0.0998</td>
#       <td id="T_b21c6_row3_col3" class="data row3 col3" >0.0779</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:562)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 4 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_39060">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_39060_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_39060_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_39060_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_39060_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39060_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39060_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_39060_row0_col1" class="data row0 col1" >1.14e+04 K</td>
#       <td id="T_39060_row0_col2" class="data row0 col2" >0.468</td>
#       <td id="T_39060_row0_col3" class="data row0 col3" >0.527</td>
#     </tr>
#     <tr>
#       <th id="T_39060_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_39060_row1_col0" class="data row1 col0" >1.05e+04 K</td>
#       <td id="T_39060_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_39060_row1_col2" class="data row1 col2" >0.181</td>
#       <td id="T_39060_row1_col3" class="data row1 col3" >0.225</td>
#     </tr>
#     <tr>
#       <th id="T_39060_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_39060_row2_col0" class="data row2 col0" >1.05e+04 K</td>
#       <td id="T_39060_row2_col1" class="data row2 col1" >1.12e+04 K</td>
#       <td id="T_39060_row2_col2" class="data row2 col2" >0.108</td>
#       <td id="T_39060_row2_col3" class="data row2 col3" >0.126</td>
#     </tr>
#     <tr>
#       <th id="T_39060_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_39060_row3_col0" class="data row3 col0" >1.03e+04 K</td>
#       <td id="T_39060_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_39060_row3_col2" class="data row3 col2" >0.0779</td>
#       <td id="T_39060_row3_col3" class="data row3 col3" >0.0926</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:562)
# [tardis.plasma.base  ][DEBUG  ]  Updating modules in the following order:TRadiative->DilutionFactor->BetaRadiation->ElectronTemperature->GElectron->LevelBoltzmannFactorLTE->JBluesDiluteBlackBody->LevelBoltzmannFactorNoNLTE->PartitionFunction->PhiSahaLTE->IonNumberDensity->LevelNumberDensity->StimulatedEmissionFactor->TauSobolev->BetaSobolev->TransitionProbabilities (base.py:264)
# [tardis.simulation.base][INFO   ]
#
# 	Simulation finished in 4 iterations
# 	Simulation took 0.36 s
#  (base.py:458)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 5 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)

# %% [markdown]
# ### What Happens When Both Parameters Are Specified? { Function & YAML Arguments }

# %% [markdown]
# If a user specifies both the parameters passed through the `log_level` & `log_level` in the **YAML** configuration file, then the `log_level` parameter *(Functional Argument)* takes precedence & is used to determine the logging level for the simulation logs.

# %% [markdown]
# Let us consider the following example for the configuration:

# %% [markdown]
# Continuing from the previous example, the `config["debug"]["log_level"]` is set to `Debug` via the **YAML** file. The user will also set the `log_level` {Functional Argument} to `Info`.

# %%
sim = run_tardis(config, log_level="Info")
# Out:
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = INFO will be used for Log Level Determination
#
# [tardis.io.model.parse_atom_data][INFO   ]
#
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (parse_atom_data.py:40)
# [tardis.io.atom_data.util][INFO   ]
#
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:36)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:258)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data, linelist (base.py:262)
# [tardis.io.model.parse_density_configuration][WARNING]
# 	Number of density points larger than number of shells. Assuming inner point irrelevant (parse_density_configuration.py:114)
# [tardis.model.matter.decay][INFO   ]
# 	Decaying abundances for 1123200.0 seconds (decay.py:101)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 1 of 5 (base.py:376)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_6ab7d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_6ab7d_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_6ab7d_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_6ab7d_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_6ab7d_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ab7d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ab7d_row0_col0" class="data row0 col0" >9.93e+03 K</td>
#       <td id="T_6ab7d_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_6ab7d_row0_col2" class="data row0 col2" >0.4</td>
#       <td id="T_6ab7d_row0_col3" class="data row0 col3" >0.481</td>
#     </tr>
#     <tr>
#       <th id="T_6ab7d_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_6ab7d_row1_col0" class="data row1 col0" >9.85e+03 K</td>
#       <td id="T_6ab7d_row1_col1" class="data row1 col1" >1.03e+04 K</td>
#       <td id="T_6ab7d_row1_col2" class="data row1 col2" >0.211</td>
#       <td id="T_6ab7d_row1_col3" class="data row1 col3" >0.193</td>
#     </tr>
#     <tr>
#       <th id="T_6ab7d_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_6ab7d_row2_col0" class="data row2 col0" >9.78e+03 K</td>
#       <td id="T_6ab7d_row2_col1" class="data row2 col1" >1.02e+04 K</td>
#       <td id="T_6ab7d_row2_col2" class="data row2 col2" >0.143</td>
#       <td id="T_6ab7d_row2_col3" class="data row2 col3" >0.112</td>
#     </tr>
#     <tr>
#       <th id="T_6ab7d_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_6ab7d_row3_col0" class="data row3 col0" >9.71e+03 K</td>
#       <td id="T_6ab7d_row3_col1" class="data row3 col1" >9.98e+03 K</td>
#       <td id="T_6ab7d_row3_col2" class="data row3 col2" >0.105</td>
#       <td id="T_6ab7d_row3_col3" class="data row3 col3" >0.0826</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 2 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_039c6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_039c6_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_039c6_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_039c6_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_039c6_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_039c6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_039c6_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_039c6_row0_col1" class="data row0 col1" >1.15e+04 K</td>
#       <td id="T_039c6_row0_col2" class="data row0 col2" >0.481</td>
#       <td id="T_039c6_row0_col3" class="data row0 col3" >0.555</td>
#     </tr>
#     <tr>
#       <th id="T_039c6_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_039c6_row1_col0" class="data row1 col0" >1.03e+04 K</td>
#       <td id="T_039c6_row1_col1" class="data row1 col1" >1.17e+04 K</td>
#       <td id="T_039c6_row1_col2" class="data row1 col2" >0.193</td>
#       <td id="T_039c6_row1_col3" class="data row1 col3" >0.203</td>
#     </tr>
#     <tr>
#       <th id="T_039c6_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_039c6_row2_col0" class="data row2 col0" >1.02e+04 K</td>
#       <td id="T_039c6_row2_col1" class="data row2 col1" >1.13e+04 K</td>
#       <td id="T_039c6_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_039c6_row2_col3" class="data row2 col3" >0.135</td>
#     </tr>
#     <tr>
#       <th id="T_039c6_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_039c6_row3_col0" class="data row3 col0" >9.98e+03 K</td>
#       <td id="T_039c6_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_039c6_row3_col2" class="data row3 col2" >0.0826</td>
#       <td id="T_039c6_row3_col3" class="data row3 col3" >0.0998</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 3 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_d521b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_d521b_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_d521b_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_d521b_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_d521b_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d521b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d521b_row0_col0" class="data row0 col0" >1.15e+04 K</td>
#       <td id="T_d521b_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_d521b_row0_col2" class="data row0 col2" >0.555</td>
#       <td id="T_d521b_row0_col3" class="data row0 col3" >0.468</td>
#     </tr>
#     <tr>
#       <th id="T_d521b_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_d521b_row1_col0" class="data row1 col0" >1.17e+04 K</td>
#       <td id="T_d521b_row1_col1" class="data row1 col1" >1.05e+04 K</td>
#       <td id="T_d521b_row1_col2" class="data row1 col2" >0.203</td>
#       <td id="T_d521b_row1_col3" class="data row1 col3" >0.181</td>
#     </tr>
#     <tr>
#       <th id="T_d521b_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_d521b_row2_col0" class="data row2 col0" >1.13e+04 K</td>
#       <td id="T_d521b_row2_col1" class="data row2 col1" >1.05e+04 K</td>
#       <td id="T_d521b_row2_col2" class="data row2 col2" >0.135</td>
#       <td id="T_d521b_row2_col3" class="data row2 col3" >0.108</td>
#     </tr>
#     <tr>
#       <th id="T_d521b_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_d521b_row3_col0" class="data row3 col0" >1.1e+04 K</td>
#       <td id="T_d521b_row3_col1" class="data row3 col1" >1.03e+04 K</td>
#       <td id="T_d521b_row3_col2" class="data row3 col2" >0.0998</td>
#       <td id="T_d521b_row3_col3" class="data row3 col3" >0.0779</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 4 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_08107">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_08107_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_08107_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_08107_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_08107_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08107_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08107_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_08107_row0_col1" class="data row0 col1" >1.14e+04 K</td>
#       <td id="T_08107_row0_col2" class="data row0 col2" >0.468</td>
#       <td id="T_08107_row0_col3" class="data row0 col3" >0.527</td>
#     </tr>
#     <tr>
#       <th id="T_08107_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_08107_row1_col0" class="data row1 col0" >1.05e+04 K</td>
#       <td id="T_08107_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_08107_row1_col2" class="data row1 col2" >0.181</td>
#       <td id="T_08107_row1_col3" class="data row1 col3" >0.225</td>
#     </tr>
#     <tr>
#       <th id="T_08107_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_08107_row2_col0" class="data row2 col0" >1.05e+04 K</td>
#       <td id="T_08107_row2_col1" class="data row2 col1" >1.12e+04 K</td>
#       <td id="T_08107_row2_col2" class="data row2 col2" >0.108</td>
#       <td id="T_08107_row2_col3" class="data row2 col3" >0.126</td>
#     </tr>
#     <tr>
#       <th id="T_08107_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_08107_row3_col0" class="data row3 col0" >1.03e+04 K</td>
#       <td id="T_08107_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_08107_row3_col2" class="data row3 col2" >0.0779</td>
#       <td id="T_08107_row3_col3" class="data row3 col3" >0.0926</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Simulation finished in 4 iterations
# 	Simulation took 0.36 s
#  (base.py:458)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 5 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)

# %% [markdown]
# A new message can be seen from the execution of the simulation,
# ```
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = Info will be used for Log Level Determination
# ```
# that is informing the user which input log level value will determine the logging level. Thus, `log_level = "Info"` is used for logging the simulation output.

# %% [markdown]
# In regards to the `specific_log_level` parameter, if any of the config input value is `True`, then `specific_log_level` will be set to `True` for the simulation output.

# %%
sim = run_tardis(config, log_level="Info", specific=True)
# Out:
# log_level is defined both in Functional Argument & YAML Configuration {debug section}
# log_level = INFO will be used for Log Level Determination
#
# [tardis.io.model.parse_atom_data][INFO   ]
#
# 	Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (parse_atom_data.py:40)
# [tardis.io.atom_data.util][INFO   ]
#
# 	Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path.
# 	Exists in TARDIS Data repo /home/runner/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:36)
# [tardis.io.atom_data.base][INFO   ]
# 	Reading Atom Data with: UUID = 6f7b09e887a311e7a06b246e96350010 MD5  = 864f1753714343c41f99cb065710cace  (base.py:258)
# [tardis.io.atom_data.base][INFO   ]
# 	Non provided Atomic Data: synpp_refs, photoionization_data, yg_data, two_photon_data, linelist (base.py:262)
# [tardis.io.model.parse_density_configuration][WARNING]
# 	Number of density points larger than number of shells. Assuming inner point irrelevant (parse_density_configuration.py:114)
# [tardis.model.matter.decay][INFO   ]
# 	Decaying abundances for 1123200.0 seconds (decay.py:101)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 1 of 5 (base.py:376)
# TqdmHBox(children=(HTML(value='Iterations:', layout=Layout(width='6%')), FloatProgress(value=0.0, layout=Layou…
# TqdmHBox(children=(HTML(value='Packets:\u2007\u2007\u2007', layout=Layout(width='6%')), FloatProgress(value=0.…
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 7.947e+42 erg / s
# 	Luminosity absorbed  = 2.654e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_cb972">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_cb972_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_cb972_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_cb972_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_cb972_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb972_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb972_row0_col0" class="data row0 col0" >9.93e+03 K</td>
#       <td id="T_cb972_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_cb972_row0_col2" class="data row0 col2" >0.4</td>
#       <td id="T_cb972_row0_col3" class="data row0 col3" >0.481</td>
#     </tr>
#     <tr>
#       <th id="T_cb972_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_cb972_row1_col0" class="data row1 col0" >9.85e+03 K</td>
#       <td id="T_cb972_row1_col1" class="data row1 col1" >1.03e+04 K</td>
#       <td id="T_cb972_row1_col2" class="data row1 col2" >0.211</td>
#       <td id="T_cb972_row1_col3" class="data row1 col3" >0.193</td>
#     </tr>
#     <tr>
#       <th id="T_cb972_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_cb972_row2_col0" class="data row2 col0" >9.78e+03 K</td>
#       <td id="T_cb972_row2_col1" class="data row2 col1" >1.02e+04 K</td>
#       <td id="T_cb972_row2_col2" class="data row2 col2" >0.143</td>
#       <td id="T_cb972_row2_col3" class="data row2 col3" >0.112</td>
#     </tr>
#     <tr>
#       <th id="T_cb972_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_cb972_row3_col0" class="data row3 col0" >9.71e+03 K</td>
#       <td id="T_cb972_row3_col1" class="data row3 col1" >9.98e+03 K</td>
#       <td id="T_cb972_row3_col2" class="data row3 col2" >0.105</td>
#       <td id="T_cb972_row3_col3" class="data row3 col3" >0.0826</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9933.952 K
# 	Expected t_inner for next iteration = 11468.808 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 2 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.413e+43 erg / s
# 	Luminosity absorbed  = 4.704e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_8be83">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_8be83_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_8be83_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_8be83_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_8be83_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8be83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8be83_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_8be83_row0_col1" class="data row0 col1" >1.15e+04 K</td>
#       <td id="T_8be83_row0_col2" class="data row0 col2" >0.481</td>
#       <td id="T_8be83_row0_col3" class="data row0 col3" >0.555</td>
#     </tr>
#     <tr>
#       <th id="T_8be83_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_8be83_row1_col0" class="data row1 col0" >1.03e+04 K</td>
#       <td id="T_8be83_row1_col1" class="data row1 col1" >1.17e+04 K</td>
#       <td id="T_8be83_row1_col2" class="data row1 col2" >0.193</td>
#       <td id="T_8be83_row1_col3" class="data row1 col3" >0.203</td>
#     </tr>
#     <tr>
#       <th id="T_8be83_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_8be83_row2_col0" class="data row2 col0" >1.02e+04 K</td>
#       <td id="T_8be83_row2_col1" class="data row2 col1" >1.13e+04 K</td>
#       <td id="T_8be83_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_8be83_row2_col3" class="data row2 col3" >0.135</td>
#     </tr>
#     <tr>
#       <th id="T_8be83_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_8be83_row3_col0" class="data row3 col0" >9.98e+03 K</td>
#       <td id="T_8be83_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_8be83_row3_col2" class="data row3 col2" >0.0826</td>
#       <td id="T_8be83_row3_col3" class="data row3 col3" >0.0998</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11468.808 K
# 	Expected t_inner for next iteration = 9929.475 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 3 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.259e+42 erg / s
# 	Luminosity absorbed  = 2.337e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_b432c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_b432c_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_b432c_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_b432c_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_b432c_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b432c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b432c_row0_col0" class="data row0 col0" >1.15e+04 K</td>
#       <td id="T_b432c_row0_col1" class="data row0 col1" >1.03e+04 K</td>
#       <td id="T_b432c_row0_col2" class="data row0 col2" >0.555</td>
#       <td id="T_b432c_row0_col3" class="data row0 col3" >0.468</td>
#     </tr>
#     <tr>
#       <th id="T_b432c_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_b432c_row1_col0" class="data row1 col0" >1.17e+04 K</td>
#       <td id="T_b432c_row1_col1" class="data row1 col1" >1.05e+04 K</td>
#       <td id="T_b432c_row1_col2" class="data row1 col2" >0.203</td>
#       <td id="T_b432c_row1_col3" class="data row1 col3" >0.181</td>
#     </tr>
#     <tr>
#       <th id="T_b432c_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_b432c_row2_col0" class="data row2 col0" >1.13e+04 K</td>
#       <td id="T_b432c_row2_col1" class="data row2 col1" >1.05e+04 K</td>
#       <td id="T_b432c_row2_col2" class="data row2 col2" >0.135</td>
#       <td id="T_b432c_row2_col3" class="data row2 col3" >0.108</td>
#     </tr>
#     <tr>
#       <th id="T_b432c_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_b432c_row3_col0" class="data row3 col0" >1.1e+04 K</td>
#       <td id="T_b432c_row3_col1" class="data row3 col1" >1.03e+04 K</td>
#       <td id="T_b432c_row3_col2" class="data row3 col2" >0.0998</td>
#       <td id="T_b432c_row3_col3" class="data row3 col3" >0.0779</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 9929.475 K
# 	Expected t_inner for next iteration = 11245.497 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 4 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 1.299e+43 erg / s
# 	Luminosity absorbed  = 4.407e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
# [tardis.simulation.base][INFO   ]
#
# 	Plasma stratification: (base.py:535)
# <style type="text/css">
# </style>
# <table id="T_6b5bf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Shell No.</th>
#       <th id="T_6b5bf_level0_col0" class="col_heading level0 col0" >t_rad</th>
#       <th id="T_6b5bf_level0_col1" class="col_heading level0 col1" >next_t_rad</th>
#       <th id="T_6b5bf_level0_col2" class="col_heading level0 col2" >w</th>
#       <th id="T_6b5bf_level0_col3" class="col_heading level0 col3" >next_w</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b5bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b5bf_row0_col0" class="data row0 col0" >1.03e+04 K</td>
#       <td id="T_6b5bf_row0_col1" class="data row0 col1" >1.14e+04 K</td>
#       <td id="T_6b5bf_row0_col2" class="data row0 col2" >0.468</td>
#       <td id="T_6b5bf_row0_col3" class="data row0 col3" >0.527</td>
#     </tr>
#     <tr>
#       <th id="T_6b5bf_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_6b5bf_row1_col0" class="data row1 col0" >1.05e+04 K</td>
#       <td id="T_6b5bf_row1_col1" class="data row1 col1" >1.13e+04 K</td>
#       <td id="T_6b5bf_row1_col2" class="data row1 col2" >0.181</td>
#       <td id="T_6b5bf_row1_col3" class="data row1 col3" >0.225</td>
#     </tr>
#     <tr>
#       <th id="T_6b5bf_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_6b5bf_row2_col0" class="data row2 col0" >1.05e+04 K</td>
#       <td id="T_6b5bf_row2_col1" class="data row2 col1" >1.12e+04 K</td>
#       <td id="T_6b5bf_row2_col2" class="data row2 col2" >0.108</td>
#       <td id="T_6b5bf_row2_col3" class="data row2 col3" >0.126</td>
#     </tr>
#     <tr>
#       <th id="T_6b5bf_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_6b5bf_row3_col0" class="data row3 col0" >1.03e+04 K</td>
#       <td id="T_6b5bf_row3_col1" class="data row3 col1" >1.1e+04 K</td>
#       <td id="T_6b5bf_row3_col2" class="data row3 col2" >0.0779</td>
#       <td id="T_6b5bf_row3_col3" class="data row3 col3" >0.0926</td>
#     </tr>
#   </tbody>
# </table>
# [tardis.simulation.base][INFO   ]
#
# 	Current t_inner = 11245.497 K
# 	Expected t_inner for next iteration = 10153.431 K
#  (base.py:562)
# [tardis.simulation.base][INFO   ]
#
# 	Simulation finished in 4 iterations
# 	Simulation took 0.35 s
#  (base.py:458)
# [tardis.simulation.base][INFO   ]
#
# 	Starting iteration 5 of 5 (base.py:376)
# [tardis.simulation.base][INFO   ]
#
# 	Luminosity emitted   = 8.742e+42 erg / s
# 	Luminosity absorbed  = 2.834e+42 erg / s
# 	Luminosity requested = 1.059e+43 erg / s
#  (base.py:567)
